# %% [markdown]
# # 00 · Setup check
#
# Confirms your environment works. Run all cells — you should see ~50/50 over `00` and `11`.

# %%
from quantumlab import circuits, run

qc = circuits.bell_state()
print(qc.draw(output='text'))

# %%
result = run.run_circuit(qc, shots=1024, save=False)
result.counts

# %%
from quantumlab import config
print('IBM token configured:', config.has_ibm_credentials())
print('If True, you can run on real hardware. If False, simulator still works.')
